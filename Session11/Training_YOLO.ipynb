# %% [markdown]
# <a href="https://colab.research.google.com/github/vivek-a81/EVA6/blob/main/Session11/Training_YOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# Forked my repo from https://github.com/theschoolofai/YoloV3.git and have added more than 100 annotated images to the pre-existing dataset.

# %%
# !git clone https://github.com/MittalNeha/YoloV3.git
# Out:
# Cloning into 'YoloV3'...
# remote: Enumerating objects: 7364, done.
# remote: Counting objects: 100% (7208/7208), done.
# remote: Compressing objects: 100% (7075/7075), done.
# remote: Total 7364 (delta 65), reused 7200 (delta 60), pack-reused 156
# Receiving objects: 100% (7364/7364), 265.31 MiB | 45.89 MiB/s, done.
# Resolving deltas: 100% (72/72), done.
# Checking out files: 100% (7488/7488), done.

# %%
# %cd YoloV3/
# Out:
# /content/YoloV3

# %% [markdown]
# Get the weights for training.
# Downloaded from: https://drive.google.com/open?id=1LezFG5g3BCW6iYaV89B2i64cqEUZD7e0
# and uploaded to my drive.

# %%
# !mkdir weights
# !cp /gdrive/MyDrive/EVA6/Session11/yolov3-spp-ultralytics.pt weights/

# %% [markdown]
# Train the model

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 3 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=3, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15109MB)
#
# 2021-07-23 19:06:02.268188: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (2960 found, 131 missing, 38 empty, 0 duplicate, for 3129 images): 100% 3129/3129 [00:00<00:00, 7886.38it/s]
# ...

# %% [markdown]
# Test Video, modified from the existing youtube video: https://www.youtube.com/watch?v=XVNMj0ZxZsI&t=220s&ab_channel=NAHBTV

# %%
# !wget https://github.com/vivek-a81/EVA6/blob/main/Session11/input/test_video.mp4
# Out:
# --2021-07-23 19:56:36--  https://github.com/vivek-a81/EVA6/blob/main/Session11/input/test_video.mp4
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘test_video.mp4’
#
# test_video.mp4          [ <=>                ] 111.70K  --.-KB/s    in 0.009s
#
# 2021-07-23 19:56:36 (12.4 MB/s) - ‘test_video.mp4’ saved [114382]

# %% [markdown]
# Extract framed from the test video

# %%
# !mkdir frames
# !ffmpeg -i "/gdrive/MyDrive/EVA6/Session11/test_video.mp4" "frames/out-%03d.jpg"
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %% [markdown]
# Run Inference on the test video frames

# %%
# !python detect.py --conf-thres 0.3 --output ../output/ --source frames/
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='../output/', save_txt=False, source='frames/', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15109MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# image 1/617 frames/out-001.jpg: 320x512 1 hardhats, Done. (0.033s)
# ...

# %%
# %cd ../output/
# Out:
# /content/output

# %% [markdown]
# Combine all the output frames to create a video

# %%
# !ffmpeg -i out-%03d.jpg ../out_video.mp4
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...
